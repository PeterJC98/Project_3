# %%
import os
import requests
import pandas as pd
import numpy as np 
import seaborn as sns 
# !pip install hvplot
import hvplot.pandas
import matplotlib.pyplot as plt
# !pip install finta
# !pip install yfinance
# !pip install YahooFinancials
#!pip install fdpf
# !pip install MCSimulation
from MCForecastTools import MCSimulation
import yfinance as yf
from finta import TA

# %matplotlib inline
#streamlit or tableau of
# Out:
# Requirement already satisfied: hvplot in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (0.7.3)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from hvplot) (2.4.2)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from hvplot) (1.14.8)
# Requirement already satisfied: colorcet>=2 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from hvplot) (2.0.6)
# Requirement already satisfied: pandas in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from hvplot) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from hvplot) (1.21.5)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from bokeh>=1.0.0->hvplot) (4.1.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from bokeh>=1.0.0->hvplot) (2.11.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from bokeh>=1.0.0->hvplot) (21.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from bokeh>=1.0.0->hvplot) (9.0.1)
# Requirement already satisfied: param>=1.7.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from colorcet>=2->hvplot) (1.12.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from colorcet>=2->hvplot) (0.4.8)
# Requirement already satisfied: panel>=0.8.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from holoviews>=1.11.0->hvplot) (0.13.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from packaging>=16.8->bokeh>=1.0.0->hvplot) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from pandas->hvplot) (2021.3)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.64.0)
# Requirement already satisfied: markdown in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.4)
# Requirement already satisfied: requests in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.27.1)
# Requirement already satisfied: bleach in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from python-dateutil>=2.7.3->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from tqdm>=4.48.0->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from bleach->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.5.1)
# Requirement already satisfied: importlib-metadata in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from importlib-metadata->markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2021.10.8)
# Requirement already satisfied: finta in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (1.3)
# Requirement already satisfied: numpy in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from finta) (1.21.5)
# Requirement already satisfied: pandas in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from finta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from pandas->finta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from pandas->finta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from python-dateutil>=2.7.3->pandas->finta) (1.16.0)
# Requirement already satisfied: yfinance in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (0.1.74)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: requests>=2.26 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: YahooFinancials in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (1.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from YahooFinancials) (4.11.1)
# Requirement already satisfied: pytz in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from YahooFinancials) (2021.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jimp\anaconda3\envs\algotrading\lib\site-packages (from beautifulsoup4->YahooFinancials) (2.3.1)
# ERROR: Could not find a version that satisfies the requirement MCSimulation (from versions: none)
# ERROR: No matching distribution found for MCSimulation
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22040\1984711250.py in <module>
#      12 #!pip install fdpf
#      13 get_ipython().system('pip install MCSimulation')
# ---> 14 from MCForecastTools import MCSimulation
#      15 import yfinance as yf
#      16 from finta import TA
#
# ModuleNotFoundError: No module named 'MCForecastTools'

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
def read_data(data, start, end):
    data1_df = yf.download(data, start, end)
    #data1_df.dropna(inplace = True)
    dataclose1_df = data1_df
    return dataclose1_df

# %%
def read_data(data, start, end):
    data_df = yf.download(data, start, end)
    #data_df.dropna(inplace = True)
    dataclose_df = data_df["Adj Close"]
    return dataclose_df

# %%
shareport = read_data(['360.AX', 'ANZ.AX', 'SQ2.AX', 'CBA.AX', 'PXA.AX', 'ALD.AX', 'AMC.AX', 'BHP.AX', 'APA.AX', 'BXB.AX', 'CHC.AX', 'COL.AX', 'WES.AX', 'CSL.AX', 'GOLD.AX', 'RMD.AX', 'TLS.AX', 'IAG.AX', 'VCX.AX', 'ANN.AX', 'JLG.AX', 'XRO.AX'],"2013-01-01","2022-07-25")
# Out:
# [*********************100%***********************]  22 of 22 completed

# %%
#shareport.dropna(inplace = True)
shareport.head()
# Out:
#             360.AX     ALD.AX    AMC.AX     ANN.AX     ANZ.AX    APA.AX  \
# 2022-07-15  0.002755  0.005614  0.019397 -0.025860  0.002545 -0.005291
# 2022-07-18 -0.009615  0.004187  0.001812  0.059730  0.002538  0.029255
# 2022-07-19 -0.011096 -0.035441 -0.045824 -0.029293 -0.005063  0.012920
# 2022-07-20  0.023843 -0.000720  0.026224  0.043705  0.005089  0.025510
# 2022-07-21  0.027397 -0.005047  0.024938  0.067099  0.015190 -0.019900
# 2022-07-22 -0.001333  0.014493  0.008411  0.006353 -0.012469  0.015228
#
#               WES.AX    XRO.AX
# Date
# 2022-06-10 -0.025006  0.040266
# 2022-06-14 -0.038241 -0.012420
# 2022-06-15 -0.006667 -0.052381
# 2022-06-16 -0.001438  0.003092
# 2022-06-17 -0.012002 -0.055620
# 2022-06-20  0.030126  0.029924
# 2022-06-21  0.012028 -0.002773
# 2022-06-22 -0.006525 -0.006754
# 2022-06-23  0.009383  0.018933
# 2022-06-24  0.018127  0.074980
# 2022-06-27  0.007761  0.011929
# 2022-06-28 -0.022877 -0.006736
# 2022-06-29 -0.010895 -0.049049
# 2022-06-30 -0.017811 -0.019868
# 2022-07-01  0.005727  0.000650
# 2022-07-04  0.025148  0.023374
# 2022-07-05  0.005554  0.023220
# 2022-07-06  0.016110  0.066468
# 2022-07-07  0.014269 -0.003837
# 2022-07-08 -0.000447  0.015992
# 2022-07-11 -0.007149 -0.031939
# 2022-07-12  0.007651  0.000237
# 2022-07-13  0.011836  0.013289
# 2022-07-14  0.004414  0.020023
# 2022-07-15  0.009229 -0.008839
# 2022-07-18  0.004790  0.019574
# 2022-07-19 -0.000867 -0.060207
# 2022-07-20  0.014964  0.059350
# 2022-07-21  0.016880  0.032634
# 2022-07-22 -0.001261  0.007956
#
# [30 rows x 22 columns]

# %%
shareport_std = sharereturns_df.std() 
shareport_std
# Out:
# 360.AX     0.041525
# ALD.AX     0.017086
# AMC.AX     0.012938
# ANN.AX     0.017715
# ANZ.AX     0.014829
# APA.AX     0.014348
# BHP.AX     0.018177
# BXB.AX     0.014202
# CBA.AX     0.013329
# CHC.AX     0.017896
# COL.AX     0.014650
# CSL.AX     0.014896
# GOLD.AX    0.020868
# IAG.AX     0.014542
# JLG.AX     0.025427
# PXA.AX     0.022144
# RMD.AX     0.016904
# SQ2.AX     0.064320
# TLS.AX     0.012323
# VCX.AX     0.017345
# WES.AX     0.012596
# XRO.AX     0.025408
# dtype: float64

# %%
ma_short = shareport.rolling(12).mean()
ma_long = shareport.rolling(28).mean()

# %%
# Compute signal for all stocks
signal = ma_short > ma_long

# Change signal type to integer
signal = signal.astype(int)

# %%
strategy_returns = signal.shift(1) * shareport.pct_change()

# Set the figure size
plt.figure(figsize=(15, 7))

# Plot the cumulative returns for all stocks
plt.plot((strategy_returns+1).cumprod())

# Set the title
plt.title('Equity Curves', fontsize=16)

# Set the labels
plt.ylabel('Cumulative Returns', fontsize=15)
plt.xlabel('Year', fontsize=15)

# Set the tick size
plt.tick_params(labelsize=15)

# Set the legend
plt.legend(['Life360', 'Ampol', 'Amcor', 'Ansell', 'ANZ', 'APA', 'BHP', 'Brambles', 'Comm Bank', 'Charter Hall', 'Coles', 'CSL', 'Gold', 'Insurance Aust', 'Johns Lyng Group','Pexa', 'Resmed', 'Square', 'Telstra', 'Vicinity Centres', 'Wesfarmers', 'Xero'],
           loc='upper left', prop={'size': 15})

# Show the graph
plt.show()

# %%
# Set weights - it is not as simple as just taking up a portfolio of equal weighted holdings, this is part of the Qualitative and Quantitative Research - to structure portfolio for best outcomes 
weights = [0.0331, 0.0331, .0591, 0.0276, 0.0539, 0.0265, 0.0713, 0.0342, 0.0692, 0.0585, 0.0394, 0.0394, .0515, 0.0651, 0.0255, 0.046, 0.0276, 0.0381, 0.0397, 0.0331, 0.0276, 0.15]

# %%
# Set the figure size
plt.figure(figsize=(15, 7))

# Plot the equal-weighted portfolio
plt.plot((strategy_returns.mean(axis=1)+1).cumprod())

# Set the title
plt.title('Balanced Portfolio Curve', fontsize=16)

# Set the labels
plt.ylabel('Cumulative Returns', fontsize=15)
plt.xlabel('Year', fontsize=15)

# Set the tick size
plt.tick_params(labelsize=15)

# Show the graph
plt.show()

# %%
#Calculate total number of days of data 
days = len(shareport)

# Compute the portfolio CAGR
cagr = ((strategy_returns.mean(axis=1)+1).cumprod().iloc[-1]**(252/days)-1)*100

# Print the CAGR
print(f'CAGR is {cagr:.2f}%')
# Out:
# CAGR is 8.46%

# %%
shareport['weighted'] = shareport.dot(weights) 
shareport
# Out:
#             360.AX     ALD.AX     AMC.AX     ANN.AX     ANZ.AX     APA.AX  \
# Date
# 2013-01-02     NaN  14.593059   4.923770  12.216581  15.123824   3.269049
# 2013-01-03     NaN  14.433783   4.978144  12.248189  15.178070   3.245231
# 2013-01-04     NaN  14.365520   4.960019  12.248189  15.226294   3.263094
# 2013-01-07     NaN  14.274498   4.960019  12.287698  15.316712   3.233322
# 2013-01-08     NaN  14.198655   5.014392  12.414130  15.172043   3.239277
# ...            ...        ...        ...        ...        ...        ...
# 2022-07-18    3.81  32.360001  18.360001  24.770000  21.468750  11.740000
# 2022-07-19    3.91  32.150002  18.000000  24.510000  21.468750  11.960000
# 2022-07-20    4.24  32.900002  18.120001  25.700001  21.468750  12.130000
# 2022-07-21    4.29  32.970001  17.969999  26.209999  21.930000  12.000000
# 2022-07-22    4.20  32.570000  18.110001  26.330000  22.590000  11.800000
#
#                BHP.AX     BXB.AX     CBA.AX     CHC.AX  ...    IAG.AX  JLG.AX  \
# Date                                                    ...
# 2013-01-02  20.873346   5.243255  39.071190   2.139085  ...  2.998736     NaN
# 2013-01-03  21.044353   5.312338  39.395111   2.171793  ...  3.017918     NaN
# 2013-01-04  20.911963   5.312338  39.401352   2.178334  ...  3.005130     NaN
# 2013-01-07  20.856798   5.305428  38.996437   2.204500  ...  3.043494     NaN
# 2013-01-08  20.685795   5.298520  38.230209   2.139085  ...  3.030705     NaN
# ...               ...        ...        ...        ...  ...       ...     ...
# 2022-07-18  36.970001  11.350000  94.239998  11.640000  ...  4.450000    7.21
# 2022-07-19  36.610001  11.320000  94.949997  11.420000  ...  4.320000    7.13
# 2022-07-20  37.110001  11.390000  96.019997  11.790000  ...  4.340000    7.30
# 2022-07-21  36.790001  11.450000  97.620003  11.640000  ...  4.270000    7.50
# 2022-07-22  36.750000  11.470000  97.800003  11.670000  ...  4.210000    7.49
#
#             PXA.AX     RMD.AX      SQ2.AX    TLS.AX    VCX.AX     WES.AX  \
# Date
# 2013-01-02     NaN   3.706673         NaN  3.053859  1.363273  16.106430
# 2013-01-03     NaN   3.715940         NaN  3.081371  1.369252  16.010944
# 2013-01-04     NaN   3.771540         NaN  3.081371  1.363273  15.997929
# 2013-01-07     NaN   3.771540         NaN  3.060737  1.351314  16.080389
# 2013-01-08     NaN   3.799341         NaN  3.067616  1.339356  15.984908
# ...            ...        ...         ...       ...       ...        ...
# 2022-07-18   14.39  33.169998   99.000000  3.950000  1.935000  46.150002
# 2022-07-19   13.88  31.650000   96.099998  3.930000  1.960000  46.110001
# 2022-07-20   13.87  32.480000  100.300003  3.950000  2.010000  46.799999
# 2022-07-21   13.80  33.290001  107.029999  4.010000  1.970000  47.590000
# 2022-07-22   14.00  33.570000  107.709999  3.960000  2.000000  47.529999
#
#                XRO.AX   weighted
# Date
# 2013-01-02   5.860000        NaN
# 2013-01-03   5.960000        NaN
# 2013-01-04   5.900000        NaN
# 2013-01-07   5.890000        NaN
# 2013-01-08   6.000000        NaN
# ...               ...        ...
# 2022-07-18  88.029999  48.821827
# 2022-07-19  82.730003  47.567897
# 2022-07-20  87.639999  48.735499
# 2022-07-21  90.500000  49.731747
# 2022-07-22  91.220001  49.860957
#
# [2420 rows x 23 columns]

# %%
risk_free_rate = 0.01/252

# Compute the portfolio Sharpe ratio
sharpe = np.sqrt(252)*(np.mean(strategy_returns.mean(axis=1)) -
                       risk_free_rate)/np.std(strategy_returns.mean(axis=1))

# Print the Sharpe ratio
print(f'Sharpe ratio is {sharpe:.2f}')
# Out:
# Sharpe ratio is 1.01

# %%
def drawdown_cal(cumulative_returns_series):

    # Calculate the running maximum
    running_max = np.maximum.accumulate(cumulative_returns_series.dropna())

    # Ensure the value never drops below 1
    running_max[running_max < 1] = 1

    # Calculate the drawdown in percentage
    drawdown = ((cumulative_returns_series)/running_max - 1) * 100

    # Return the maximum drawdown and the drawdown series
    return drawdown.min(), drawdown

# Use the function compute the drawdown and its maximum value
mdd, drawdown = drawdown_cal((strategy_returns.mean(axis=1)+1).cumprod())

# %%
# Set the figure size
plt.figure(figsize=(15, 7))

# Plot the portfolio drawdown series
plt.plot(drawdown, color='r')

# Set the title
plt.title('Portfolio Drawdown', fontsize=16)

# Set the labels
plt.ylabel('Drawdown in %', fontsize=15)
plt.xlabel('Date', fontsize=15)

# Set the tick size
plt.tick_params(labelsize=15)

# Fill the space between 0 and the drawdown with red color
plt.fill_between(strategy_returns.index, drawdown, alpha=0.5, color='r')

# Show the graph
plt.show()

# %%
# Print the maximum drawdown
print(f'Maximum Drawdown is {mdd:.2f}%')
# Out:
# Maximum Drawdown is -12.67%

# %%
# Calculate the percentage change
shareport['weighted'] = shareport['weighted'].pct_change()

# Plot the percentage change
plt.figure(figsize=(15,7))
shareport['weighted'].plot()

# Set the title and axes label
plt.title('Returns', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Percentage Change', fontsize=12)

# Show the plot
plt.show()

# %%
algoport = read_data(['ANZ.AX', 'AMC.AX', 'BHP.AX', 'WES.AX', 'CSL.AX', 'GOLD.AX'],"2008-01-01","2022-07-25")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
algoport.dropna(inplace = True)
algoport.head()
# Out:
#               AMC.AX     ANZ.AX     BHP.AX     CSL.AX    GOLD.AX     WES.AX
# Date
# 2008-01-02  2.686118  12.384183  19.283703  28.839651  95.220001  11.422432
# 2008-01-03  2.670546  12.276378  19.188004  28.784449  97.010002  11.478492
# 2008-01-04  2.654975  12.312310  19.546885  27.987949  97.779999  11.428041
# 2008-01-07  2.623831  11.988891  19.149723  27.207218  99.370003  11.215009
# 2008-01-08  2.682225  12.015842  18.661648  27.869656  97.620003  11.206597

# %%
algocsl = algoport.drop(['AMC.AX', 'ANZ.AX', 'BHP.AX', 'GOLD.AX', 'WES.AX'], axis = 1)
algocsl
# Out:
#                 CSL.AX
# Date
# 2008-01-02   28.839651
# 2008-01-03   28.784449
# 2008-01-04   27.987949
# 2008-01-07   27.207218
# 2008-01-08   27.869656
# ...                ...
# 2022-07-18  296.660004
# 2022-07-19  290.660004
# 2022-07-20  291.230011
# 2022-07-21  295.239990
# 2022-07-22  293.470001
#
# [3682 rows x 1 columns]

# %%
# Set 10 as the lookback period of the short-term moving average
shortterm_lookback = 9

# Set 24 as the lookback period of the long-term moving average
longterm_lookback = 21

# Store short-term moving average values in the column 'ma_short'
algocsl['ma_short'] = algocsl['CSL.AX'].rolling(shortterm_lookback).mean()

# Store long-term moving average values in the column 'ma_long'
algocsl['ma_long'] = algocsl['CSL.AX'].rolling(longterm_lookback).mean()

algocsl.tail()
# Out:
#                 CSL.AX    ma_short     ma_long
# Date
# 2022-07-18  296.660004  291.897780  279.022382
# 2022-07-19  290.660004  292.401113  280.338097
# 2022-07-20  291.230011  292.871114  281.825240
# 2022-07-21  295.239990  293.747779  283.419525
# 2022-07-22  293.470001  294.356669  284.656192

# %%
# Create a column 'signal' to store the relative position of moving averages
algocsl['signal'] = np.where(algocsl.ma_short > algocsl.ma_long, 1, 0)
algocsl
# Out:
#                 CSL.AX    ma_short     ma_long  signal
# Date
# 2008-01-02   28.839651         NaN         NaN       0
# 2008-01-03   28.784449         NaN         NaN       0
# 2008-01-04   27.987949         NaN         NaN       0
# 2008-01-07   27.207218         NaN         NaN       0
# 2008-01-08   27.869656         NaN         NaN       0
# ...                ...         ...         ...     ...
# 2022-07-18  296.660004  291.897780  279.022382       1
# 2022-07-19  290.660004  292.401113  280.338097       1
# 2022-07-20  291.230011  292.871114  281.825240       1
# 2022-07-21  295.239990  293.747779  283.419525       1
# 2022-07-22  293.470001  294.356669  284.656192       1
#
# [3682 rows x 4 columns]

# %%
days = 300

# Plot the close prices of the last 300 days
close_plot = algocsl['CSL.AX'][-days:].plot(figsize=(15, 7), color='blue')

# Plot the signal of the last 100 days
signal_plot = algocsl.signal[-days:].plot(figsize=(15, 7),
                                       secondary_y=True, ax=close_plot, style='green')

# Highlight the holding periods of the long positions
plt.fill_between(algocsl['CSL.AX'][-days:].index, 0, 1,
                 where=(algocsl.signal[-days:] > 0), color='green', alpha=0.1, lw=0)

# Title of the plot
signal_plot.set_title('Visualising The Holding Periods of The Long Positions - CSL')

# Plot ylabels
close_plot.set_ylabel('Price ($)')
signal_plot.set_ylabel('Signal')

# Legend of the plot
plt.legend()

# Show the plot
plt.show()

# %%
# Calculate strategy returns
strategy_returns = algoport.signal.shift(1)*algoport['CSL.AX'].pct_change()

# Total strategy returns
print(f'Total strategy returns: {strategy_returns.sum():.2f} %')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22040\2572928368.py in <module>
#       1 # Calculate strategy returns
# ----> 2 strategy_returns = algoport.signal.shift(1)*algoport['CSL.AX'].pct_change()
#       3
#       4 # Total strategy returns
#       5 print(f'Total strategy returns: {strategy_returns.sum():.2f} %')
#
# ~\anaconda3\envs\algotrading\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'signal'

# %%
# Create a column 'long_cross_over' to store the long crossover conditions
algocsl['long_cross_over'] = np.where((algocsl['ma_short'].shift(
    1) < algocsl['ma_long'].shift(1)) & (algocsl['ma_short'] >= algocsl['ma_long']), True, False)
algocsl.tail(50)
# Out:
#                 CSL.AX    ma_short     ma_long  signal  long_cross_over
# Date
# 2022-05-13  280.200012  273.408888  269.670000       1            False
# 2022-05-16  277.250000  273.895555  270.397619       1            False
# 2022-05-17  274.070007  273.820001  270.926668       1            False
# 2022-05-18  273.089996  273.468889  271.314286       1            False
# 2022-05-19  274.000000  274.117778  271.869048       1            False
# 2022-05-20  275.170013  274.647780  272.377143       1            False
# 2022-05-23  273.149994  274.925557  272.670952       1            False
# 2022-05-24  274.149994  274.695557  272.827619       1            False
# 2022-05-25  273.600006  274.964447  273.030477       1            False
# 2022-05-26  269.890015  273.818892  273.220953       1            False
# 2022-05-27  269.019989  272.904446  273.229524       0            False
# 2022-05-30  274.000000  272.896667  273.262858       0            False
# 2022-05-31  271.829987  272.756666  273.328571       0            False
# 2022-06-01  273.500000  272.701111  273.358571       0            False
# 2022-06-02  268.619995  271.973331  273.066666       0            False
# 2022-06-03  269.000000  271.512221  272.721428       0            False
# 2022-06-06  270.859985  271.146664  272.849999       0            False
# 2022-06-07  267.679993  270.488885  272.720475       0            False
# 2022-06-08  270.899994  270.601105  272.732380       0            False
# 2022-06-09  271.690002  270.897773  272.516666       0            False
# 2022-06-10  271.380005  270.606662  272.526190       0            False
# 2022-06-14  264.049988  269.742218  271.757141       0            False
# 2022-06-15  260.890015  268.341109  270.978094       0            False
# 2022-06-16  258.679993  267.236664  270.245236       0            False
# 2022-06-17  255.990005  265.791109  269.430951       0            False
# 2022-06-20  263.029999  264.921110  268.908570       0            False
# 2022-06-21  260.000000  264.067778  268.186188       0            False
# 2022-06-22  261.760010  263.052224  267.643808       0            False
# 2022-06-23  267.500000  262.586668  267.327142       0            False
# 2022-06-24  271.250000  262.572223  267.215237       0            False
# 2022-06-27  273.000000  263.566669  267.363331       0            False
# 2022-06-28  274.029999  265.026667  267.601903       0            False
# 2022-06-29  269.790009  266.261113  267.401427       0            False
# 2022-06-29  269.790009  266.261113  267.401427       0            False
# 2022-06-30  269.059998  267.713335  267.269523       1             True
# 2022-07-01  269.230011  268.402225  267.066190       1            False
# 2022-07-04  274.799988  270.046668  267.360476       1            False
# 2022-07-05  278.940002  271.955556  267.833809       1            False
# 2022-07-06  286.130005  274.025557  268.560953       1            False
# 2022-07-07  287.000000  275.775557  269.480953       1            False
# 2022-07-08  287.350006  277.370002  270.264287       1            False
# 2022-07-11  287.989990  278.921112  271.040477       1            False
# 2022-07-12  292.690002  281.465556  272.055239       1            False
# 2022-07-13  293.809998  284.215556  273.472382       1            False
# 2022-07-14  296.200012  287.212223  275.153811       1            False
# 2022-07-15  299.250000  289.928891  277.085716       1            False
# 2022-07-18  296.660004  291.897780  279.022382       1            False
# 2022-07-19  290.660004  292.401113  280.338097       1            False
# 2022-07-20  291.230011  292.871114  281.825240       1            False
# 2022-07-21  295.239990  293.747779  283.419525       1            False
# 2022-07-22  293.470001  294.356669  284.656192       1            False
#
#             exit_cross_over
# Date
# 2022-05-13            False
# 2022-05-16            False
# 2022-05-17            False
# 2022-05-18            False
# 2022-05-19            False
# 2022-05-20            False
# 2022-05-23            False
# 2022-05-24            False
# 2022-05-25            False
# 2022-05-26            False
# 2022-05-27             True
# 2022-05-30            False
# 2022-05-31            False
# 2022-06-01            False
# 2022-06-02            False
# 2022-06-03            False
# 2022-06-06            False
# 2022-06-07            False
# 2022-06-08            False
# 2022-06-09            False
# 2022-06-10            False
# 2022-06-14            False
# 2022-06-15            False
# 2022-06-16            False
# 2022-06-17            False
# 2022-06-20            False
# 2022-06-21            False
# 2022-06-22            False
# 2022-06-23            False
# 2022-06-24            False
# 2022-06-27            False
# 2022-06-28            False
# 2022-06-29            False
# 2022-06-30            False
# 2022-07-01            False
# 2022-07-04            False
# 2022-07-05            False
# 2022-07-06            False
# 2022-07-07            False
# 2022-07-08            False
# 2022-07-11            False
# 2022-07-12            False
# 2022-07-13            False
# 2022-07-14            False
# 2022-07-15            False
# 2022-07-18            False
# 2022-07-19            False
# 2022-07-20            False
# 2022-07-21            False
# 2022-07-22            False

# %%
def backtest_trade_sheet(algocsl, long_crossover_column, exit_crossover_column):
# Out:
#   File "C:\Users\jimp\AppData\Local\Temp\ipykernel_22040\3639291255.py", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
# Create a dataframe 'trade_sheet' to store the trades
trade_sheet = pd.DataFrame()

# %%
# Initialise the current_position as '0'
current_position = 0

# %%
# Define a variable to store the long entry date
entry_date = ''

# Define a variable to store the long entry price
entry_price = ''

# Define a variable to store the long exit date
exit_date = ''

# Define a variable to store the long exit price
exit_price = ''

# %%
# Iterate over the dates in the dataframe 'data'
for current_date in algocsl.index:
    # Define the variable 'long_crossover' that stores the long crossover condition on the current_date
    long_crossover = algocsl.loc[current_date, 'long_cross_over']

    # Define the variable 'exit_crossover' that stores the exit crossover condition on date current_date
    exit_crossover = algocsl.loc[current_date, 'exit_cross_over']

    # We will enter the long position if we are not holding any position and the entry condition is met
    if current_position == 0 and long_crossover == True:

        # Define the variable 'entry_date'
        entry_date = current_date

        # Extract the 'Close price' of the current_date and store it the variable 'entry price'
        entry_price = algocsl.loc[entry_date, 'CSL.AX']

        # Long position is opened so update the current_position to '1'
        current_position = 1

    # We will exit the long position if we are holding a long position and the exit condition is met
    elif current_position == 1 and exit_crossover == True:

        # Define the variable 'exit_date'
        exit_date = current_date

        # Extract the 'Close price' on the current_date and store in the variable 'exit price'
        exit_price = algocsl.loc[exit_date, 'CSL.AX']

        # Append the details of this trade to the 'trade_sheet' dataframe
        trade_sheet = trade_sheet.append(
            [(current_position, entry_date, entry_price, exit_date, exit_price)], ignore_index=True)

        # Long position is closed so update the current_position to '0'
        current_position = 0

# Define the names of columns in 'trade_sheet' dataframe
trade_sheet.columns = ['Position', 'Entry Date',
                       'Entry Price', 'Exit Date', 'Exit Price']

trade_sheet.tail(50)
# Out:
#     Position Entry Date  Entry Price  Exit Date  Exit Price
# 44         1 2014-09-29    66.534210 2014-10-13   65.211502
# 45         1 2014-10-23    67.856934 2014-11-25   72.024376
# 46         1 2014-11-28    74.805695 2015-01-14   77.750069
# 47         1 2015-02-02    79.815681 2015-02-20   81.265236
# 48         1 2015-02-24    82.651382 2015-04-07   85.484688
# 49         1 2015-04-10    86.863762 2015-04-29   83.110115
# 50         1 2015-05-27    84.406990 2015-06-12   81.557503
# 51         1 2015-07-10    80.425026 2015-08-17   85.731285
# 52         1 2015-09-17    83.440460 2015-09-22   83.329742
# 53         1 2015-09-28    83.726425 2015-09-30   82.287315
# 54         1 2015-10-13    82.591743 2015-10-14   82.333443
# 55         1 2015-10-15    82.093590 2015-10-16   82.379578
# 56         1 2015-10-27    85.276245 2016-01-15   95.276184
# 57         1 2016-01-22    98.929291 2016-02-10   93.652565
# 58         1 2016-03-08    94.492043 2016-03-21   92.711617
# 59         1 2016-04-18    96.129509 2016-06-16  101.662743
# 60         1 2016-07-08   102.750778 2016-08-10  107.344772
# 61         1 2016-09-27   101.426941 2016-10-18   98.781029
# 62         1 2016-11-18    94.061539 2016-11-28   92.382034
# 63         1 2016-12-23    91.762787 2017-05-23  123.839134
# 64         1 2017-06-13   130.026367 2017-07-07  126.739098
# 65         1 2017-08-25   121.430351 2017-12-11  134.526245
# 66         1 2018-01-09   134.973297 2018-02-12  133.413376
# 67         1 2018-02-19   148.251846 2018-03-28  150.255676
# 68         1 2018-04-19   152.925690 2018-08-02  188.171310
# 69         1 2018-08-13   193.597412 2018-09-12  204.061386
# 70         1 2018-11-07   181.310898 2018-11-21  172.116333
# 71         1 2018-12-13   174.889114 2018-12-14  173.444946
# 72         1 2018-12-17   176.901321 2018-12-20  169.112427
# 73         1 2018-12-28   179.548996 2019-02-06  181.792282
# 74         1 2019-03-04   191.506699 2019-03-27  186.300217
# 75         1 2019-04-03   196.015762 2019-04-23  184.401657
# 76         1 2019-05-07   192.363937 2019-06-11  205.837875
# 77         1 2019-06-13   205.973511 2019-08-12  215.795563
# 78         1 2019-08-20   227.099701 2019-09-16  224.520615
# 79         1 2019-09-30   227.746429 2020-01-03  270.247253
# 80         1 2020-01-10   291.687683 2020-03-02  298.324463
# 81         1 2020-04-02   301.867004 2020-04-30  303.012695
# 82         1 2020-06-25   287.893402 2020-07-10  276.504974
# 83         1 2020-08-13   272.029907 2020-09-07  276.269958
# 84         1 2020-09-23   292.566803 2020-10-30  283.067596
# 85         1 2020-11-12   303.759186 2020-12-03  289.534943
# 86         1 2021-02-03   275.881622 2021-02-26  258.487671
# 87         1 2021-03-25   266.963440 2021-06-30  282.160248
# 88         1 2021-07-23   290.362213 2021-09-15  303.200500
# 89         1 2021-09-23   311.265808 2021-09-30  291.783722
# 90         1 2021-10-21   293.026855 2021-12-03  296.030243
# 91         1 2022-02-22   265.509308 2022-03-09  257.000000
# 92         1 2022-03-18   270.959991 2022-04-12  261.970001
# 93         1 2022-04-28   268.839996 2022-05-27  269.019989

# %%
# Save the trades generated in the dataframe 'crossover_trade_sheet'
crossover_trade_sheet = backtest_trade_sheet(
    algocsl, 'Close', 'long_cross_over', 'exit_cross_over')

# Calculate PnL for each trade
crossover_trade_sheet['PnL'] = (crossover_trade_sheet['Exit Price'] -
                                crossover_trade_sheet['Entry Price']) * crossover_trade_sheet['Position']

# Print the total profit/loss by summing up the PnL of each trade.
print(f'The total PnL of trades generated between 2010-01-01 and 2022-05-31 is $',
      round(crossover_trade_sheet.PnL.sum(), 2))

# Print the last 5 rows of the 'crossover_trade_sheet' dataframe
crossover_trade_sheet.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22040\2554262098.py in <module>
#       1 # Save the trades generated in the dataframe 'crossover_trade_sheet'
# ----> 2 crossover_trade_sheet = backtest_trade_sheet(
#       3     algocsl, 'Close', 'long_cross_over', 'exit_cross_over')
#       4
#       5 # Calculate PnL for each trade
#
# NameError: name 'backtest_trade_sheet' is not defined

# %%
# Define a variable to store the stop loss percentage
stop_loss_percentage = 0.09

# Define a variable to store the take profit percentage
take_profit_percentage = 0.14
    # Step-5: We will enter the long position if we are not holding any position and entry condition is met
    if current_position == 0 and long_crossover == True:

        # Define the variable 'entry_date'
        entry_date = current_date

        # Extract the 'Close price' on the current_date and store in the variable 'entry price'
        entry_price = data.loc[entry_date, 'Close']

        # Since a new long position is opened, change the state of current_position to '1'
        current_position = 1

    # Step-6: We will exit the long position if we are holding long position and exit condition is met
    elif current_position == 1 and exit_crossover == True:

        # Define the variable 'exit_date'
        exit_date = current_date

        # Extract the 'Close price' on the current_date and store in the variable 'exit price'
        exit_price = data.loc[exit_date, 'Close']        

        # Exit type is 'exit_crossover'
        exit_type = 'exit_crossover'

        # Append the details of this trade to the 'trade_sheet' dataframe
        trade_sheet = trade_sheet.append(
            [(current_position, entry_date, entry_price, exit_date, exit_price, exit_type)], ignore_index=True)

        # Since a new long position is closed, change the state of current_position to '0'
        current_position = 0

# Define the names of columns in 'trade_sheet' dataframe
trade_sheet.columns = ['Position', 'Entry Date',
                  'Entry Price', 'Exit Date', 'Exit Price', 'Exit Type']

trade_sheet.tail()
# Out:
#   File "C:\Users\jimp\AppData\Local\Temp\ipykernel_22040\2877271117.py", line 7
#     if current_position == 0 and long_crossover == True:
#     ^
# IndentationError: unexpected indent
